# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\siddh\\OneDrive\\Desktop\\siddhardh\\retail\\retail_sales.xlsx")
print(df)
# Out:
#     order_id  order_date region         category sub_category    product_name  \
# 0       1001  2024-01-10  South        Furniture       Chairs    Office Chair
# 1       1002  2024-02-15  North       Technology       Phones      Smartphone
# 2       1003  2024-03-05   East  Office Supplies      Binders     Ring Binder
# 3       1004  2024-04-12   West        Furniture       Tables    Dining Table
# 4       1005  2024-05-20  South       Technology  Accessories           Mouse
# 5       1006  2024-06-18  North  Office Supplies        Paper  A4 Sheets Pack
# 6       1007  2024-07-25   East        Furniture       Chairs   Plastic Chair
# 7       1008  2024-08-30   West       Technology      Laptops   Gaming Laptop
# 8       1009  2024-09-10  South  Office Supplies         Pens   Ball Pen Pack
# 9       1010  2024-10-05  North        Furniture       Tables     Study Table
# 10      1011  2024-11-11   East       Technology       Phones          iPhone
# 11      1012  2024-12-22   West  Office Supplies      Binders     Clip Binder
# 12      1013  2024-01-18  South        Furniture       Tables    Coffee Table
# 13      1014  2024-02-25  North       Technology  Accessories        Keyboard
# 14      1015  2024-03-30   East  Office Supplies        Paper        Notebook
#
#     sales   cost  profit  quantity  inventory_days  season
# 0    5000   3500    1500         2              45  Winter
# 1   20000  15000    5000         3              20  Winter
# 2    2000   1200     800         5              60  Spring
# 3   15000  12000    3000         1              70  Spring
# 4     800    400     400        10              15  Summer
# 5    1200    800     400        20              10  Summer
# 6    3000   2500     500         6              90  Summer
# 7   70000  65000    5000         1              25   Rainy
# 8     500    300     200        15               5   Rainy
# 9    8000   7000    1000         2              50  Autumn
# 10  90000  85000    5000         1              30  Autumn
# 11   1500   1000     500         4              40  Winter
# 12   6000   5000    1000         2              65  Winter
# 13   1500    900     600         8              18  Winter
# 14   1000    600     400        10              35  Spring

# %%
corr = df[["inventory_days","profit"]].corr()
print(corr)
# Out:
#                 inventory_days    profit
# inventory_days        1.000000 -0.092109
# profit               -0.092109  1.000000

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Inventory Days vs Profit")
plt.show()

# %%
sns.barplot(x='category', y='profit', data=df)
plt.title("Profit by Category")
plt.show()

# %%
plt.bar(df["category"],df["profit"])
plt.xlabel("categories")
plt.ylabel("profits")
plt.show()
